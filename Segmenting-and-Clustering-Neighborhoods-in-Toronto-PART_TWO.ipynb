# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto: PART TWO
#
# ## By Katarzyna Cybulska
#
# This is notebook two of three containing steps in segmentation and clustering of neighborhoods in Toronto. In this workbook we will find coordinates of neighborhoods in Toronto. Enjoy!

# %% [markdown]
# # Import packages
# Besides standard packages we will also import geocoder to be used to find coordinates of Postal Codes in Toronto.

# %%
#import packages

import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)


! pip install msgpack
! pip install geocoder
import geocoder # import geocoder


print('Libraries imported.')
# Out:
# ...
# Libraries imported.

# %% [markdown]
# # Find coordinates of Postal Codes in Toronto.

# %%
#Caution: run code from Segmenting-and-Clustering-Neighborhoods-in-Toronto-PART_ONE first to get toronto_neighborhoods data frame.

# initialize new columns in toronto_neighborhoods data frame to store coordinates
toronto_neighborhoods['Latitude']=''
toronto_neighborhoods['Longitude']=''

# initialize your variable to None
lat_lng_coords = None


# loop through postal codes in toronto_neighborhoods data frame and assing coordinates in new columns

for postal_code in toronto_neighborhoods['PostalCode']:

    # loop until you get the coordinates
    while(lat_lng_coords is None):
        #find coordinates for given postal code
        g = geocoder.google('{}, Toronto, Ontario'.format(postal_code))
        lat_lng_coords = g.latlng
        
    #store coordinates in data frame
    toronto_neighborhoods.loc[toronto_neighborhoods['PostalCode'] == postal_code, unique_postal_codes.columns[3]] = lat_lng_coords[0]
    toronto_neighborhoods.loc[toronto_neighborhoods['PostalCode'] == postal_code, unique_postal_codes.columns[4]] = lat_lng_coords [1]

#display table extended with coordinates
toronto_neighborhoods.head(10)
# Out:
#    PostalCode           Borough      Neighborhood Latitude Longitude
# 0         M3A        North York         Parkwoods  43.7533  -79.3297
# 1         M4A        North York  Victoria Village  43.7533  -79.3297
# 2         M5A  Downtown Toronto      Harbourfront  43.7533  -79.3297
# 4         M6A        North York  Lawrence Heights  43.7533  -79.3297
# 6         M7A      Queen's Park      Queen's Park  43.7533  -79.3297
# 7         M9A         Etobicoke  Islington Avenue  43.7533  -79.3297
# 8         M1B       Scarborough             Rouge  43.7533  -79.3297
# 10        M3B        North York   Don Mills North  43.7533  -79.3297
# 11        M4B         East York  Woodbine Gardens  43.7533  -79.3297
# 13        M5B  Downtown Toronto           Ryerson  43.7533  -79.3297

# %% [markdown]
# # Done!
#
# Remember to check rest of the exercise in notebook Segmenting-and-Clustering-Neighborhoods-in-Toronto-PART_THREE.
#
# # Thank you for reading!
